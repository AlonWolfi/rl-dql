# %%
# %load_ext autoreload
# %autoreload 2

import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('statistics.pkl', 'rb') as f:
    statistics = pickle.load(f)
plt.plot(statistics['mean_episode_rewards'])
statistics.keys()
# Out:
# dict_keys(['mean_episode_rewards', 'best_mean_episode_rewards'])

# %%
with open('losses.pkl', 'rb') as f:
    losses = pickle.load(f)

plt.plot(losses)

# %%
with open('losses_clipped.pkl', 'rb') as f:
    losses_clipped = pickle.load(f)

plt.plot(losses_clipped[20:])

# %%
N = 1000
plt.plot(np.convolve(losses[20:], np.ones(N)/N, mode='valid'))

# %%
N = 1000
plt.plot(np.convolve(losses_clipped, np.ones(N)/N, mode='valid'))
